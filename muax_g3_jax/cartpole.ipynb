# %% [markdown]
# ### Env

# %%
from cartpole_jax_env import CartPole

# %% [markdown]
# ### Train

# %%
import gymnasium as gym 
import jax
import jax.numpy as jnp
import numpy as np

class JaxToGymWrapper(gym.Env):
    """
    Wraps a pure JAX environment to make it compatible with the 
    gymnasium/Gym API expected by the training loop.
    """
    def __init__(self, jax_env, seed=42):
        self.env = jax_env
        self.params = jax_env.default_params
        self._key = jax.random.PRNGKey(seed)
        self._state = None
        
        # Convert JAX spaces to Gym spaces for compatibility
        # Observation space (Box)
        high = np.array([
            self.params.x_threshold * 2,
            np.finfo(np.float32).max,
            self.params.theta_threshold_radians * 2,
            np.finfo(np.float32).max
        ], dtype=np.float32)
        self.observation_space = gym.spaces.Box(-high, high, shape=(4,), dtype=np.float32)
        
        # Action space (Discrete)
        self.action_space = gym.spaces.Discrete(2)
        
        # Mock the 'spec' attribute accessed in the fit loop
        # The loop calls: range(env.spec.max_episode_steps)
        class EnvSpec:
            max_episode_steps = self.params.max_steps_in_episode
            id = "JaxCartPole-v1"
        self.spec = EnvSpec()

    def reset(self, seed=None, options=None):
        # Handle seeding
        if seed is not None:
            self._key = jax.random.PRNGKey(seed)
            
        self._key, subkey = jax.random.split(self._key)
        
        # JIT compilation happens automatically on the first call here
        obs, self._state = self.env.reset(subkey, self.params)
        
        # Convert jax array to numpy for the buffer/tracer
        return np.array(obs), {}

    def step(self, action):
        self._key, subkey = jax.random.split(self._key)
        
        # Step the JAX env
        obs, self._state, reward, done, info = self.env.step(
            subkey, self._state, action, self.params
        )
        
        # Determine truncated (time limit) vs terminated (failure)
        # The JAX env combines them into 'done', but we can inspect time
        truncated = self._state.time >= self.params.max_steps_in_episode
        terminated = bool(done) and not truncated
        
        return np.array(obs), float(reward), terminated, truncated, info

    def render(self):
        # Expose the JAX render function
        return np.array(self.env.render(self._state, self.params))
# Out:
# /n/home04/amuppidi/.conda/envs/torch/lib/python3.10/site-packages/gym/envs/registration.py:323: DeprecationWarning: The package name gym_minigrid has been deprecated in favor of minigrid. Please uninstall gym_minigrid and install minigrid with `pip install minigrid`. Future releases will be maintained under the new package name minigrid.
#   fn()
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card4: Permission denied
#
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card3: Permission denied
#
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card2: Permission denied
#
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# /n/home04/amuppidi/.conda/envs/torch/lib/python3.10/site-packages/requests/__init__.py:43: DeprecationWarning: 'urllib3[secure]' extra is deprecated and will be removed in a future release of urllib3 2.x. Read more in this issue: https://github.com/urllib3/urllib3/issues/2680
#   import urllib3

# %%
jax_cartpole = CartPole()

# 2. Wrap it to look like a Gym environment
# We create two separate instances to keep training and testing random states separate
train_env = JaxToGymWrapper(jax_cartpole, seed=42)


# reset
obs, info = train_env.reset()

# sample action
action = train_env.action_space.sample()

# step
obs, reward, terminated, truncated, info = train_env.step(action)

# %%
key = jax.random.PRNGKey(0)
env = CartPole()
params = env.default_params  # optional; you can also skip and use default

# reset
key, subkey = jax.random.split(key)
obs, state = env.reset(subkey, params)

# step
key, subkey = jax.random.split(key)

# sample action
action = env.action_space(params).sample(subkey)

# step
obs, new_state, reward, done, info = env.step(subkey, state, action, params)

# %%
key, subkey = jax.random.split(key)
obs_space = env.observation_space(params)
sample_input = jnp.expand_dims(
    obs_space.sample(subkey), axis=0
).astype(float)
sample_input
# Out:
# Array([[1.7698131,       inf, 0.2091639,       inf]], dtype=float32)

# %%
import time
import math


class TrainMonitor:
    """
    Extremely lightweight training monitor for your pure-JAX CartPole.

    Usage:
        mon = TrainMonitor()

        # at the start of an episode:
        mon.begin_episode()

        # each environment step:
        mon.step(
            reward,
            v=v_value,
            Rn=return_n,
            loss=loss_value,
            training_step=global_training_step,
        )

        # when episode terminates:
        mon.end_episode()
    """

    def __init__(self, smoothing: int = 10):
        self.smoothing = float(smoothing)
        self.reset_global()

    # ---------- global counters ----------

    def reset_global(self):
        self.T = 0              # global steps
        self.ep = 0             # episodes
        self.t = 0              # steps in current episode
        self.G = 0.0            # return in current episode
        self.avg_G = 0.0        # smoothed return
        self._n_avg_G = 0.0
        self._ep_start_time = time.time()
        self._last_metrics = {}
        self._in_episode = False

    # ---------- derived properties ----------

    @property
    def avg_r(self) -> float:
        if self.t == 0:
            return math.nan
        return self.G / self.t

    @property
    def dt_ms(self) -> float:
        if self.t == 0:
            return math.nan
        return 1000.0 * (time.time() - self._ep_start_time) / self.t

    # ---------- episode lifecycle ----------

    def begin_episode(self):
        """Call once after env.reset() at the start of an episode."""
        if self._in_episode:
            # if user forgot to end previous episode, close it
            self.end_episode()

        self.ep += 1
        self.t = 0
        self.G = 0.0
        self._ep_start_time = time.time()
        self._last_metrics = {}
        self._in_episode = True

    def step(self, reward: float, **metrics):
        """
        Call every environment step.

        `reward` is the scalar environment reward (Python float).
        Extra metrics (v, Rn, loss, training_step, etc.) can be passed as kwargs.
        Only the LAST values in the episode are printed.
        """
        if not self._in_episode:
            # allow using step() without explicit begin_episode()
            self.begin_episode()

        self.T += 1
        self.t += 1
        self.G += float(reward)

        # store last seen metrics for this episode
        self._last_metrics.update(metrics)

    def end_episode(self):
        """Call when the episode terminates (done=True)."""
        if not self._in_episode:
            return
        self._in_episode = False

        # update running avg_G
        if self._n_avg_G < self.smoothing:
            self._n_avg_G += 1.0
        self.avg_G += (self.G - self.avg_G) / self._n_avg_G

        self._print_line()

    # ---------- printing ----------

    def _print_line(self):
        avg_r = self.avg_r
        dt = self.dt_ms

        # Optional metrics; default to NaN if not provided
        v = float(self._last_metrics.get("v", math.nan))
        Rn = float(self._last_metrics.get("Rn", math.nan))
        loss = float(self._last_metrics.get("loss", math.nan))
        training_step = float(self._last_metrics.get("training_step", math.nan))

        # Format similar to your example
        msg = (
            "[TrainMonitor|INFO] "
            f"ep: {self.ep},\t"
            f"T: {self.T:,},\t"
            f"G: {self.G:.0f},\t"
            f"avg_r: {avg_r:.3g},\t"
            f"avg_G: {self.avg_G:.1f},\t"
            f"t: {self.t},\t"
            f"dt: {dt:.3f}ms,\t"
            f"v: {v:.1f},\t"
            f"Rn: {Rn:.1f},\t"
            f"loss: {loss:.2f},\t"
            f"training_step: {training_step:.2e}"
        )
        print(msg)

# %%
import jax
import jax.numpy as jnp

env = CartPole()
params = env.default_params
key = jax.random.PRNGKey(0)

monitor = TrainMonitor(smoothing=100)

global_training_step = 0.0  # e.g., your optimizer step counter

for episode in range(1000):
    # reset env
    key, subkey = jax.random.split(key)
    obs, state = env.reset(subkey, params)

    monitor.begin_episode()

    done = False
    while not bool(done):
        # --- choose action (dummy random policy here) ---
        key, akey, skey = jax.random.split(key, 3)
        action = env.action_space(params).sample(akey)

        # step env
        obs, state, reward, done, info = env.step(skey, state, action, params)

        # suppose you have these training stats from your agent:
        v = 44.4             # value estimate
        Rn = 45.7            # n-step return
        loss = 2.52          # loss
        global_training_step += 1.0

        monitor.step(
            float(reward),
            v=v,
            Rn=Rn,
            loss=loss,
            training_step=global_training_step,
        )

    # episode finished
    monitor.end_episode()
# Out:
# [TrainMonitor|INFO] ep: 1,	T: 28,	G: 28,	avg_r: 1,	avg_G: 28.0,	t: 28,	dt: 14.797ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 2.80e+01
# [TrainMonitor|INFO] ep: 2,	T: 44,	G: 16,	avg_r: 1,	avg_G: 22.0,	t: 16,	dt: 6.338ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 4.40e+01
# [TrainMonitor|INFO] ep: 3,	T: 62,	G: 18,	avg_r: 1,	avg_G: 20.7,	t: 18,	dt: 6.341ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 6.20e+01
# [TrainMonitor|INFO] ep: 4,	T: 78,	G: 16,	avg_r: 1,	avg_G: 19.5,	t: 16,	dt: 6.386ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 7.80e+01
# [TrainMonitor|INFO] ep: 5,	T: 97,	G: 19,	avg_r: 1,	avg_G: 19.4,	t: 19,	dt: 6.272ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 9.70e+01
# [TrainMonitor|INFO] ep: 6,	T: 114,	G: 17,	avg_r: 1,	avg_G: 19.0,	t: 17,	dt: 6.317ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.14e+02
# [TrainMonitor|INFO] ep: 7,	T: 145,	G: 31,	avg_r: 1,	avg_G: 20.7,	t: 31,	dt: 6.372ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.45e+02
# [TrainMonitor|INFO] ep: 8,	T: 160,	G: 15,	avg_r: 1,	avg_G: 20.0,	t: 15,	dt: 6.181ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.60e+02
# [TrainMonitor|INFO] ep: 9,	T: 176,	G: 16,	avg_r: 1,	avg_G: 19.6,	t: 16,	dt: 6.203ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.76e+02
# [TrainMonitor|INFO] ep: 10,	T: 205,	G: 29,	avg_r: 1,	avg_G: 20.5,	t: 29,	dt: 6.372ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 2.05e+02
# [TrainMonitor|INFO] ep: 11,	T: 215,	G: 10,	avg_r: 1,	avg_G: 19.5,	t: 10,	dt: 6.162ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 2.15e+02
# [TrainMonitor|INFO] ep: 12,	T: 234,	G: 19,	avg_r: 1,	avg_G: 19.5,	t: 19,	dt: 6.134ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 2.34e+02
# [TrainMonitor|INFO] ep: 13,	T: 246,	G: 12,	avg_r: 1,	avg_G: 18.9,	t: 12,	dt: 6.278ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 2.46e+02
# [TrainMonitor|INFO] ep: 14,	T: 273,	G: 27,	avg_r: 1,	avg_G: 19.5,	t: 27,	dt: 6.202ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 2.73e+02
# [TrainMonitor|INFO] ep: 15,	T: 283,	G: 10,	avg_r: 1,	avg_G: 18.9,	t: 10,	dt: 6.302ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 2.83e+02
# [TrainMonitor|INFO] ep: 16,	T: 316,	G: 33,	avg_r: 1,	avg_G: 19.8,	t: 33,	dt: 6.282ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 3.16e+02
# [TrainMonitor|INFO] ep: 17,	T: 329,	G: 13,	avg_r: 1,	avg_G: 19.4,	t: 13,	dt: 6.721ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 3.29e+02
# [TrainMonitor|INFO] ep: 18,	T: 347,	G: 18,	avg_r: 1,	avg_G: 19.3,	t: 18,	dt: 6.279ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 3.47e+02
# [TrainMonitor|INFO] ep: 19,	T: 370,	G: 23,	avg_r: 1,	avg_G: 19.5,	t: 23,	dt: 6.260ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 3.70e+02
# [TrainMonitor|INFO] ep: 20,	T: 388,	G: 18,	avg_r: 1,	avg_G: 19.4,	t: 18,	dt: 6.245ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 3.88e+02
# [TrainMonitor|INFO] ep: 21,	T: 409,	G: 21,	avg_r: 1,	avg_G: 19.5,	t: 21,	dt: 6.240ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 4.09e+02
# [TrainMonitor|INFO] ep: 22,	T: 419,	G: 10,	avg_r: 1,	avg_G: 19.0,	t: 10,	dt: 6.138ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 4.19e+02
# [TrainMonitor|INFO] ep: 23,	T: 431,	G: 12,	avg_r: 1,	avg_G: 18.7,	t: 12,	dt: 6.304ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 4.31e+02
# [TrainMonitor|INFO] ep: 24,	T: 460,	G: 29,	avg_r: 1,	avg_G: 19.2,	t: 29,	dt: 6.232ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 4.60e+02
# [TrainMonitor|INFO] ep: 25,	T: 468,	G: 8,	avg_r: 1,	avg_G: 18.7,	t: 8,	dt: 6.415ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 4.68e+02
# [TrainMonitor|INFO] ep: 26,	T: 478,	G: 10,	avg_r: 1,	avg_G: 18.4,	t: 10,	dt: 6.301ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 4.78e+02
# [TrainMonitor|INFO] ep: 27,	T: 491,	G: 13,	avg_r: 1,	avg_G: 18.2,	t: 13,	dt: 6.178ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 4.91e+02
# [TrainMonitor|INFO] ep: 28,	T: 529,	G: 38,	avg_r: 1,	avg_G: 18.9,	t: 38,	dt: 6.282ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 5.29e+02
# [TrainMonitor|INFO] ep: 29,	T: 545,	G: 16,	avg_r: 1,	avg_G: 18.8,	t: 16,	dt: 9.909ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 5.45e+02
# [TrainMonitor|INFO] ep: 30,	T: 555,	G: 10,	avg_r: 1,	avg_G: 18.5,	t: 10,	dt: 6.827ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 5.55e+02
# [TrainMonitor|INFO] ep: 31,	T: 581,	G: 26,	avg_r: 1,	avg_G: 18.7,	t: 26,	dt: 6.213ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 5.81e+02
# [TrainMonitor|INFO] ep: 32,	T: 624,	G: 43,	avg_r: 1,	avg_G: 19.5,	t: 43,	dt: 6.338ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 6.24e+02
# [TrainMonitor|INFO] ep: 33,	T: 641,	G: 17,	avg_r: 1,	avg_G: 19.4,	t: 17,	dt: 6.183ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 6.41e+02
# [TrainMonitor|INFO] ep: 34,	T: 660,	G: 19,	avg_r: 1,	avg_G: 19.4,	t: 19,	dt: 6.217ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 6.60e+02
# [TrainMonitor|INFO] ep: 35,	T: 685,	G: 25,	avg_r: 1,	avg_G: 19.6,	t: 25,	dt: 6.188ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 6.85e+02
# [TrainMonitor|INFO] ep: 36,	T: 704,	G: 19,	avg_r: 1,	avg_G: 19.6,	t: 19,	dt: 6.220ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 7.04e+02
# [TrainMonitor|INFO] ep: 37,	T: 727,	G: 23,	avg_r: 1,	avg_G: 19.6,	t: 23,	dt: 6.293ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 7.27e+02
# [TrainMonitor|INFO] ep: 38,	T: 744,	G: 17,	avg_r: 1,	avg_G: 19.6,	t: 17,	dt: 6.347ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 7.44e+02
# [TrainMonitor|INFO] ep: 39,	T: 765,	G: 21,	avg_r: 1,	avg_G: 19.6,	t: 21,	dt: 6.270ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 7.65e+02
# [TrainMonitor|INFO] ep: 40,	T: 787,	G: 22,	avg_r: 1,	avg_G: 19.7,	t: 22,	dt: 6.448ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 7.87e+02
# [TrainMonitor|INFO] ep: 41,	T: 800,	G: 13,	avg_r: 1,	avg_G: 19.5,	t: 13,	dt: 6.314ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 8.00e+02
# [TrainMonitor|INFO] ep: 42,	T: 812,	G: 12,	avg_r: 1,	avg_G: 19.3,	t: 12,	dt: 6.132ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 8.12e+02
# [TrainMonitor|INFO] ep: 43,	T: 825,	G: 13,	avg_r: 1,	avg_G: 19.2,	t: 13,	dt: 6.237ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 8.25e+02
# [TrainMonitor|INFO] ep: 44,	T: 850,	G: 25,	avg_r: 1,	avg_G: 19.3,	t: 25,	dt: 6.207ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 8.50e+02
# [TrainMonitor|INFO] ep: 45,	T: 867,	G: 17,	avg_r: 1,	avg_G: 19.3,	t: 17,	dt: 6.215ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 8.67e+02
# [TrainMonitor|INFO] ep: 46,	T: 883,	G: 16,	avg_r: 1,	avg_G: 19.2,	t: 16,	dt: 6.220ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 8.83e+02
# [TrainMonitor|INFO] ep: 47,	T: 898,	G: 15,	avg_r: 1,	avg_G: 19.1,	t: 15,	dt: 6.178ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 8.98e+02
# [TrainMonitor|INFO] ep: 48,	T: 921,	G: 23,	avg_r: 1,	avg_G: 19.2,	t: 23,	dt: 6.310ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 9.21e+02
# [TrainMonitor|INFO] ep: 49,	T: 991,	G: 70,	avg_r: 1,	avg_G: 20.2,	t: 70,	dt: 6.175ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 9.91e+02
# [TrainMonitor|INFO] ep: 50,	T: 1,005,	G: 14,	avg_r: 1,	avg_G: 20.1,	t: 14,	dt: 6.132ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.00e+03
# [TrainMonitor|INFO] ep: 51,	T: 1,021,	G: 16,	avg_r: 1,	avg_G: 20.0,	t: 16,	dt: 6.126ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.02e+03
# [TrainMonitor|INFO] ep: 52,	T: 1,042,	G: 21,	avg_r: 1,	avg_G: 20.0,	t: 21,	dt: 6.252ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.04e+03
# [TrainMonitor|INFO] ep: 53,	T: 1,077,	G: 35,	avg_r: 1,	avg_G: 20.3,	t: 35,	dt: 6.288ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.08e+03
# [TrainMonitor|INFO] ep: 54,	T: 1,095,	G: 18,	avg_r: 1,	avg_G: 20.3,	t: 18,	dt: 6.289ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.10e+03
# [TrainMonitor|INFO] ep: 55,	T: 1,117,	G: 22,	avg_r: 1,	avg_G: 20.3,	t: 22,	dt: 6.241ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.12e+03
# [TrainMonitor|INFO] ep: 56,	T: 1,133,	G: 16,	avg_r: 1,	avg_G: 20.2,	t: 16,	dt: 6.246ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.13e+03
# [TrainMonitor|INFO] ep: 57,	T: 1,143,	G: 10,	avg_r: 1,	avg_G: 20.1,	t: 10,	dt: 6.234ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.14e+03
# [TrainMonitor|INFO] ep: 58,	T: 1,156,	G: 13,	avg_r: 1,	avg_G: 19.9,	t: 13,	dt: 6.239ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.16e+03
# [TrainMonitor|INFO] ep: 59,	T: 1,176,	G: 20,	avg_r: 1,	avg_G: 19.9,	t: 20,	dt: 6.173ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.18e+03
# [TrainMonitor|INFO] ep: 60,	T: 1,192,	G: 16,	avg_r: 1,	avg_G: 19.9,	t: 16,	dt: 6.227ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.19e+03
# [TrainMonitor|INFO] ep: 61,	T: 1,211,	G: 19,	avg_r: 1,	avg_G: 19.9,	t: 19,	dt: 6.209ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.21e+03
# [TrainMonitor|INFO] ep: 62,	T: 1,223,	G: 12,	avg_r: 1,	avg_G: 19.7,	t: 12,	dt: 6.130ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.22e+03
# [TrainMonitor|INFO] ep: 63,	T: 1,244,	G: 21,	avg_r: 1,	avg_G: 19.7,	t: 21,	dt: 6.349ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.24e+03
# [TrainMonitor|INFO] ep: 64,	T: 1,270,	G: 26,	avg_r: 1,	avg_G: 19.8,	t: 26,	dt: 6.204ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.27e+03
# [TrainMonitor|INFO] ep: 65,	T: 1,288,	G: 18,	avg_r: 1,	avg_G: 19.8,	t: 18,	dt: 6.240ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.29e+03
# [TrainMonitor|INFO] ep: 66,	T: 1,307,	G: 19,	avg_r: 1,	avg_G: 19.8,	t: 19,	dt: 6.238ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.31e+03
# [TrainMonitor|INFO] ep: 67,	T: 1,323,	G: 16,	avg_r: 1,	avg_G: 19.7,	t: 16,	dt: 6.199ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.32e+03
# [TrainMonitor|INFO] ep: 68,	T: 1,333,	G: 10,	avg_r: 1,	avg_G: 19.6,	t: 10,	dt: 6.131ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.33e+03
# [TrainMonitor|INFO] ep: 69,	T: 1,353,	G: 20,	avg_r: 1,	avg_G: 19.6,	t: 20,	dt: 6.197ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.35e+03
# [TrainMonitor|INFO] ep: 70,	T: 1,373,	G: 20,	avg_r: 1,	avg_G: 19.6,	t: 20,	dt: 6.263ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.37e+03
# [TrainMonitor|INFO] ep: 71,	T: 1,418,	G: 45,	avg_r: 1,	avg_G: 20.0,	t: 45,	dt: 6.223ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.42e+03
# [TrainMonitor|INFO] ep: 72,	T: 1,433,	G: 15,	avg_r: 1,	avg_G: 19.9,	t: 15,	dt: 6.291ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.43e+03
# [TrainMonitor|INFO] ep: 73,	T: 1,453,	G: 20,	avg_r: 1,	avg_G: 19.9,	t: 20,	dt: 6.218ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.45e+03
# [TrainMonitor|INFO] ep: 74,	T: 1,473,	G: 20,	avg_r: 1,	avg_G: 19.9,	t: 20,	dt: 6.210ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.47e+03
# [TrainMonitor|INFO] ep: 75,	T: 1,498,	G: 25,	avg_r: 1,	avg_G: 20.0,	t: 25,	dt: 6.179ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.50e+03
# [TrainMonitor|INFO] ep: 76,	T: 1,514,	G: 16,	avg_r: 1,	avg_G: 19.9,	t: 16,	dt: 6.202ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.51e+03
# [TrainMonitor|INFO] ep: 77,	T: 1,525,	G: 11,	avg_r: 1,	avg_G: 19.8,	t: 11,	dt: 6.195ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.52e+03
# [TrainMonitor|INFO] ep: 78,	T: 1,545,	G: 20,	avg_r: 1,	avg_G: 19.8,	t: 20,	dt: 6.230ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.54e+03
# [TrainMonitor|INFO] ep: 79,	T: 1,560,	G: 15,	avg_r: 1,	avg_G: 19.7,	t: 15,	dt: 6.539ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.56e+03
# [TrainMonitor|INFO] ep: 80,	T: 1,578,	G: 18,	avg_r: 1,	avg_G: 19.7,	t: 18,	dt: 6.835ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.58e+03
# [TrainMonitor|INFO] ep: 81,	T: 1,590,	G: 12,	avg_r: 1,	avg_G: 19.6,	t: 12,	dt: 6.124ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.59e+03
# [TrainMonitor|INFO] ep: 82,	T: 1,610,	G: 20,	avg_r: 1,	avg_G: 19.6,	t: 20,	dt: 6.259ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.61e+03
# [TrainMonitor|INFO] ep: 83,	T: 1,630,	G: 20,	avg_r: 1,	avg_G: 19.6,	t: 20,	dt: 6.235ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.63e+03
# [TrainMonitor|INFO] ep: 84,	T: 1,677,	G: 47,	avg_r: 1,	avg_G: 20.0,	t: 47,	dt: 6.220ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.68e+03
# [TrainMonitor|INFO] ep: 85,	T: 1,693,	G: 16,	avg_r: 1,	avg_G: 19.9,	t: 16,	dt: 6.238ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.69e+03
# [TrainMonitor|INFO] ep: 86,	T: 1,727,	G: 34,	avg_r: 1,	avg_G: 20.1,	t: 34,	dt: 6.282ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.73e+03
# [TrainMonitor|INFO] ep: 87,	T: 1,744,	G: 17,	avg_r: 1,	avg_G: 20.0,	t: 17,	dt: 6.201ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.74e+03
# [TrainMonitor|INFO] ep: 88,	T: 1,756,	G: 12,	avg_r: 1,	avg_G: 20.0,	t: 12,	dt: 6.114ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.76e+03
# [TrainMonitor|INFO] ep: 89,	T: 1,768,	G: 12,	avg_r: 1,	avg_G: 19.9,	t: 12,	dt: 6.278ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.77e+03
# [TrainMonitor|INFO] ep: 90,	T: 1,784,	G: 16,	avg_r: 1,	avg_G: 19.8,	t: 16,	dt: 6.245ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.78e+03
# [TrainMonitor|INFO] ep: 91,	T: 1,835,	G: 51,	avg_r: 1,	avg_G: 20.2,	t: 51,	dt: 6.205ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.84e+03
# [TrainMonitor|INFO] ep: 92,	T: 1,849,	G: 14,	avg_r: 1,	avg_G: 20.1,	t: 14,	dt: 6.113ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.85e+03
# [TrainMonitor|INFO] ep: 93,	T: 1,864,	G: 15,	avg_r: 1,	avg_G: 20.0,	t: 15,	dt: 6.188ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.86e+03
# [TrainMonitor|INFO] ep: 94,	T: 1,877,	G: 13,	avg_r: 1,	avg_G: 20.0,	t: 13,	dt: 6.554ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.88e+03
# [TrainMonitor|INFO] ep: 95,	T: 1,901,	G: 24,	avg_r: 1,	avg_G: 20.0,	t: 24,	dt: 6.363ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.90e+03
# [TrainMonitor|INFO] ep: 96,	T: 1,911,	G: 10,	avg_r: 1,	avg_G: 19.9,	t: 10,	dt: 6.262ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.91e+03
# [TrainMonitor|INFO] ep: 97,	T: 1,930,	G: 19,	avg_r: 1,	avg_G: 19.9,	t: 19,	dt: 6.187ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.93e+03
# [TrainMonitor|INFO] ep: 98,	T: 1,957,	G: 27,	avg_r: 1,	avg_G: 20.0,	t: 27,	dt: 6.190ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.96e+03
# [TrainMonitor|INFO] ep: 99,	T: 1,981,	G: 24,	avg_r: 1,	avg_G: 20.0,	t: 24,	dt: 6.162ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 1.98e+03
# [TrainMonitor|INFO] ep: 100,	T: 2,028,	G: 47,	avg_r: 1,	avg_G: 20.3,	t: 47,	dt: 6.261ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 2.03e+03
# [TrainMonitor|INFO] ep: 101,	T: 2,042,	G: 14,	avg_r: 1,	avg_G: 20.2,	t: 14,	dt: 6.216ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 2.04e+03
# [TrainMonitor|INFO] ep: 102,	T: 2,059,	G: 17,	avg_r: 1,	avg_G: 20.2,	t: 17,	dt: 6.200ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 2.06e+03
# [TrainMonitor|INFO] ep: 103,	T: 2,077,	G: 18,	avg_r: 1,	avg_G: 20.2,	t: 18,	dt: 6.417ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 2.08e+03
# [TrainMonitor|INFO] ep: 104,	T: 2,113,	G: 36,	avg_r: 1,	avg_G: 20.3,	t: 36,	dt: 6.216ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 2.11e+03
# [TrainMonitor|INFO] ep: 105,	T: 2,158,	G: 45,	avg_r: 1,	avg_G: 20.6,	t: 45,	dt: 6.199ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 2.16e+03
# [TrainMonitor|INFO] ep: 106,	T: 2,167,	G: 9,	avg_r: 1,	avg_G: 20.5,	t: 9,	dt: 6.263ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 2.17e+03
# [TrainMonitor|INFO] ep: 107,	T: 2,178,	G: 11,	avg_r: 1,	avg_G: 20.4,	t: 11,	dt: 6.196ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 2.18e+03
# [TrainMonitor|INFO] ep: 108,	T: 2,192,	G: 14,	avg_r: 1,	avg_G: 20.3,	t: 14,	dt: 6.259ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 2.19e+03
# [TrainMonitor|INFO] ep: 109,	T: 2,203,	G: 11,	avg_r: 1,	avg_G: 20.2,	t: 11,	dt: 6.122ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 2.20e+03
# [TrainMonitor|INFO] ep: 110,	T: 2,215,	G: 12,	avg_r: 1,	avg_G: 20.1,	t: 12,	dt: 6.252ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 2.22e+03
# [TrainMonitor|INFO] ep: 111,	T: 2,258,	G: 43,	avg_r: 1,	avg_G: 20.3,	t: 43,	dt: 6.214ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 2.26e+03
# [TrainMonitor|INFO] ep: 112,	T: 2,272,	G: 14,	avg_r: 1,	avg_G: 20.3,	t: 14,	dt: 6.092ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 2.27e+03
# [TrainMonitor|INFO] ep: 113,	T: 2,296,	G: 24,	avg_r: 1,	avg_G: 20.3,	t: 24,	dt: 6.147ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 2.30e+03
# [TrainMonitor|INFO] ep: 114,	T: 2,314,	G: 18,	avg_r: 1,	avg_G: 20.3,	t: 18,	dt: 6.190ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 2.31e+03
# [TrainMonitor|INFO] ep: 115,	T: 2,332,	G: 18,	avg_r: 1,	avg_G: 20.3,	t: 18,	dt: 6.198ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 2.33e+03
# [TrainMonitor|INFO] ep: 116,	T: 2,360,	G: 28,	avg_r: 1,	avg_G: 20.4,	t: 28,	dt: 6.181ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 2.36e+03
# [TrainMonitor|INFO] ep: 117,	T: 2,386,	G: 26,	avg_r: 1,	avg_G: 20.4,	t: 26,	dt: 6.222ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 2.39e+03
# [TrainMonitor|INFO] ep: 118,	T: 2,407,	G: 21,	avg_r: 1,	avg_G: 20.4,	t: 21,	dt: 6.103ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 2.41e+03
# [TrainMonitor|INFO] ep: 119,	T: 2,425,	G: 18,	avg_r: 1,	avg_G: 20.4,	t: 18,	dt: 6.206ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 2.42e+03
# [TrainMonitor|INFO] ep: 120,	T: 2,447,	G: 22,	avg_r: 1,	avg_G: 20.4,	t: 22,	dt: 6.161ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 2.45e+03
# [TrainMonitor|INFO] ep: 121,	T: 2,465,	G: 18,	avg_r: 1,	avg_G: 20.4,	t: 18,	dt: 6.198ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 2.46e+03
# [TrainMonitor|INFO] ep: 122,	T: 2,506,	G: 41,	avg_r: 1,	avg_G: 20.6,	t: 41,	dt: 7.036ms,	v: 44.4,	Rn: 45.7,	loss: 2.52,	training_step: 2.51e+03
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 26
#      23 action = env.action_space(params).sample(akey)
#      25 # step env
# ---> 26 obs, state, reward, done, info = env.step(skey, state, action, params)
#      28 # suppose you have these training stats from your agent:
#      29 v = 44.4             # value estimate
#
# Cell In[1], line 209, in CartPole.step(self, key, state, action, params)
#     207 if params is None:
#     208     params = self.default_params
# --> 209 return self.step_env(key, state, action, params)
#
# Cell In[1], line 148, in CartPole.step_env(***failed resolving arguments***)
#     145 xacc = temp - polemass_length * thetaacc * costheta / total_mass
#     147 # Euler integration
# --> 148 x = state.x + params.tau * state.x_dot
#     149 x_dot = state.x_dot + params.tau * xacc
#     150 theta = state.theta + params.tau * state.theta_dot
#
# File ~/.conda/envs/torch/lib/python3.10/site-packages/jax/_src/numpy/array_methods.py:583, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#     581 args = (other, self) if swap else (self, other)
#     582 if isinstance(other, _accepted_binop_types):
# --> 583   return binary_op(*args)
#     584 # Note: don't use isinstance here, because we don't want to raise for
#     585 # subclasses, e.g. NamedTuple objects that may override operators.
#     586 if type(other) in _rejected_binop_types:
#
# File ~/.conda/envs/torch/lib/python3.10/site-packages/jax/_src/numpy/ufunc_api.py:182, in ufunc.__call__(self, out, where, *args)
#     180   raise NotImplementedError(f"where argument of {self}")
#     181 call = self.__static_props['call'] or self._call_vectorized
# --> 182 return call(*args)
#
# KeyboardInterrupt:
